# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>

# %% [markdown]
# # 6.0 The Riva Contact Application
# ## (part of Lab 1)

# %% [markdown]
# In this notebook, you'll launch the Riva contact app with default ASR and NER (named entity recognition) services that you can try out for yourself!
#
# <img src="images/asr/contact-app-default.png">

# %% [markdown]
# **[6.1 Riva Contact](#6.1-Riva-Contact)<br>**
# **[6.2 Start the Riva ASR/NLP Services](#6.2-Start-the-Riva-ASR/NLP-Services)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[6.2.1 Exercise: Configure Riva for Streaming ASR and NER](#6.2.1-Exercise:-Configure-Riva-for-Streaming-ASR-and-NER)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.2.2 Start Riva Services](#6.2.2-Start-Riva-Services)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.2.3 Riva Available Services Check](#6.2.3-Riva-Available-Services-Check)<br>
# **[6.3 Run the Application Service](#6.3-Run-the-Application-Service)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[6.3.1 Start the Contact Web Server](#6.3.1-Start-the-Contact-Web-Server)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.3.2 Direct NER](#6.3.2-Direct-NER)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[6.3.3 Stop Riva Services](#6.3.3-Stop-Riva-Services)<br>

# %% [markdown]
# ### Notebook Dependencies
# To run this app on your system, you will need:
# 1. **Microphone**<br>
# For best ASR results, a headset is recommended.
# 1. **Chrome browser**<br>
# In order to use the app over HTTP in our class setup, you will need to override the browser block to your camera and microphone.  Instructions are included later in the notebook.
# 1. **NGC Credentials**<br>Be sure you have added your NGC credential as described in the [NGC Setup notebook](003_Intro_NGC_Setup.ipynb)

# %%
# Check running docker containers. This should be empty.
# !docker ps
# Out:
# CONTAINER ID   IMAGE                                               COMMAND                  CREATED          STATUS          PORTS                                                                                                 NAMES
# cf9703a1ed3a   nvcr.io/nvidia/riva/riva-speech:1.4.0-beta-server   "/opt/riva/nvidia_en…"   10 minutes ago   Up 10 minutes   0.0.0.0:50051->50051/tcp, 0.0.0.0:49164->8000/tcp, 0.0.0.0:49163->8001/tcp, 0.0.0.0:49162->8002/tcp   riva-speech

# %%
# If not empty,
# Clear Docker containers to start fresh...
# !docker kill $(docker ps -q)
# Check for clean environment - this should be empty
# !docker ps
# Out:
# cf9703a1ed3a
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %% [markdown]
# ---
# # 6.1 Riva Contact

# %% [markdown]
# Riva provides sample applications showing several use cases for virtual assistants and call centers. More about those samples can be found in the [Riva samples documentation](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/).
#
#
# Riva Contact (from the [Riva Contact Center Video Conference sample](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/samples/callcenter.html)), is a web-based demonstration application for contact applications powered by conversational AI technologies.
# It is a peer-to-peer video conferencing app using streaming ASR and NLP.
# The application is based on a lightweight Node.js and backed by the robust NVIDIA Riva AI Services.
#
# In the background, each user’s web client sends a separate audio stream to the Riva Contact server. The server makes a streaming gRPC call to hosted Riva AI Services, which return an ongoing stream of ASR transcripts. This stream of transcripts is handed back to the speaker’s web client, with in-progress results that may change as the user speaks.
#
# When ASR results are marked as "final" (typically during short pauses in speech), the server hands the resulting transcript over to the NLP service for named entity recognition (NER). If Riva is configured to use a general-domain NER model, the service will recognize entities like the name of a person, location, or organization.
#
# Once the NER results are complete, the application server returns the final transcript and its NER annotation back to the web client. The web client then exchanges transcripts with the other user for an ongoing, annotated transcript of the conversation.
#
# <img src="images/asr/riva-contact-architecture.png" width=1000>
#
# Riva Contact is a Node.js application, intended to run in a Linux environment. It requires Riva Speech Services to be running with two primary models:
# - Streaming ASR
# - Named Entity Recognition (NER)
#
# You can use the default ASR and NER models available in `riva/models`.  Alternatively, you can deploy your own trained custom models for a specific domain - something you will try for yourself in a later notebook!

# %% [markdown]
# ---
# # 6.2 Start the Riva ASR/NLP Services
# To deploy Riva AI Services, we can use the Riva Quick Start scripts as we did in the earlier [ASR deployment notebook](005_ASR_Riva_Deployment.ipynb), to set up a local workspace and deploy the Riva services using Docker.

# %%
# Set the workspace path to "/path/to/your/workspace"
WORKSPACE = "/dli/task"

# Set the location of the models directory
RIVA_MODEL_LOC = WORKSPACE + "/riva"

# Set the Riva Quick Start directory
RIVA_QS = WORKSPACE + "/riva/riva_quickstart"

# %% [markdown]
# Riva Quick Start configuration offers a list of available ASR, NLP and TTS models that can be downloaded from NGC and optimized for the target hardware.
# This process can take several minutes.  To save time, _the default Riva models have already been downloaded and optimized for the platform in `riva/models`_.
# If you wish to download any of these on your own system, you can uncomment the desired models in the Riva `config.sh` file and they can be downloaded using the [`riva_init.sh` command](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/custom-model-deployment.html?highlight=riva_init%20sh).

# %%
# Check available default riva models 
# !ls $RIVA_MODEL_LOC/models
# Out:
# denoiser
# quartznet-asr-trt-ensemble-vad-streaming
# quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming
# quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming
# quartznet-asr-trt-ensemble-vad-streaming-offline
# quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline
# quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline
# quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline
# quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming
# riva-trt-quartznet
# riva-trt-riva_intent_weather-nn-bert-base-uncased
# riva-trt-riva_ner-nn-bert-base-uncased
# riva-trt-riva_punctuation-nn-bert-base-uncased
# riva-trt-riva_qa-nn-bert-base-uncased
# riva-trt-riva_text_classification_domain-nn-bert-base-uncased
# riva-trt-tacotron2_encoder
# riva-trt-waveglow
# riva_detokenize
# riva_intent_weather
# riva_label_tokens_weather
# riva_ner
# riva_ner_label_tokens
# riva_punctuation
# riva_punctuation_gen_output
# riva_punctuation_label_tokens_cap
# riva_punctuation_label_tokens_punct
# riva_punctuation_merge_labels
# riva_qa
# riva_qa_postprocessor
# riva_qa_preprocessor
# riva_text_classification_domain
# riva_tokenizer
# tacotron2_decoder_postnet
# tacotron2_ensemble
# tts_preprocessor

# %% [markdown]
# Since the models are already downloaded and optimized, we don't need to run the `riva_init.sh` script and can move straight to starting the server.

# %% [markdown]
# ## 6.2.1 Exercise: Configure Riva for Streaming ASR and NER
# To expose Riva ASR and NLP services, modify [config.sh](riva/riva_quickstart/config.sh) to
# - Enable ASR and NLP Riva services
# - Provide the encryption key (should already be correct)
# - Specify the correct model repository path to `riva_model_loc`

# %% [markdown]
# Check your work against the [solution](solutions/ex6.2.1.sh) before moving on to the next section.  You can verify it with `diff` in the next cell. You should get no "difference" (an empty output) if your config file matches the solution.
#
# Note that it would generally be necessary to also uncomment the models needed from NGC for streaming ASR and NER in the configuration file.  In this lab, it is not necessary because they've already been downloaded.

# %%
# TODO modify config.sh so that this cell verifies changes are correct
# There should be no output if the files match
# !diff $RIVA_QS/config.sh solutions/ex6.2.1.sh

# %% [markdown]
# ## 6.2.2 Start Riva Services
#
# Now, we are ready to start the Riva server with ASR and NLP services. We'll first initialize with `riva_init.sh`.  The `riva_start.sh` script starts the server.

# %%
# Ensure you have permission to execute these scripts.
# !cd $RIVA_QS && chmod +x *.sh

# %%
# Initialize Riva
# !cd $RIVA_QS && bash riva_init.sh config.sh
# Out:
# Logging into NGC docker registry if necessary...
# Pulling required docker images if necessary...
# Note: This may take some time, depending on the speed of your Internet connection.
# > Pulling Riva Speech Server images.
#   > Image nvcr.io/nvidia/riva/riva-speech:1.4.0-beta-server exists. Skipping.
#   > Image nvcr.io/nvidia/riva/riva-speech-client:1.4.0-beta exists. Skipping.
#   > Image nvcr.io/nvidia/riva/riva-speech:1.4.0-beta-servicemaker exists. Skipping.
#
# Downloading models (RMIRs) from NGC...
# Note: this may take some time, depending on the speed of your Internet connection.
# To skip this process and use existing RMIRs set the location and corresponding flag in config.sh.
#
# ==========================
# === Riva Speech Skills ===
# ==========================
#
# NVIDIA Release devel (build 22382700)
#
# Copyright (c) 2018-2021, NVIDIA CORPORATION.  All rights reserved.
#
# Various files include modifications (c) NVIDIA CORPORATION.  All rights reserved.
# NVIDIA modifications are covered by the license terms that apply to the underlying
# project or file.
#
# NOTE: Legacy NVIDIA Driver detected.  Compatibility mode ENABLED.
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for the inference server.  NVIDIA recommends the use of the following flags:
#    nvidia-docker run --shm-size=1g --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# /data/artifacts /opt/riva
# /opt/riva
#
# Converting RMIRs at /dli/task/riva/rmir to Riva Model repository.
# + docker run --init -it --rm --gpus '"device=0"' -v /dli/task/riva:/data -e MODEL_DEPLOY_KEY=tlt_encode --name riva-service-maker nvcr.io/nvidia/riva/riva-speech:1.4.0-beta-servicemaker deploy_all_models /data/rmir /data/models
#
# ==========================
# === Riva Speech Skills ===
# ==========================
#
# NVIDIA Release devel (build 22382700)
#
# Copyright (c) 2018-2021, NVIDIA CORPORATION.  All rights reserved.
#
# Various files include modifications (c) NVIDIA CORPORATION.  All rights reserved.
# NVIDIA modifications are covered by the license terms that apply to the underlying
# project or file.
#
# NOTE: Legacy NVIDIA Driver detected.  Compatibility mode ENABLED.
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for the inference server.  NVIDIA recommends the use of the following flags:
#    nvidia-docker run --shm-size=1g --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# 2022-06-22 10:23:43,299 [INFO] Writing Riva model repository to '/data/models'...
# 2022-06-22 10:23:43,299 [INFO] The riva model repo target directory is /data/models
# 2022-06-22 10:23:48,420 [WARNING] /data/models/tts_preprocessor already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/tts_preprocessor
# 2022-06-22 10:23:48,421 [WARNING] /data/models/riva-trt-tacotron2_encoder already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-tacotron2_encoder
# 2022-06-22 10:23:48,421 [WARNING] /data/models/tacotron2_decoder_postnet already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/tacotron2_decoder_postnet
# 2022-06-22 10:23:48,421 [WARNING] /data/models/riva-trt-waveglow already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-waveglow
# 2022-06-22 10:23:48,421 [WARNING] /data/models/denoiser already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/denoiser
# 2022-06-22 10:23:48,421 [WARNING] /data/models/tacotron2_ensemble already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/tacotron2_ensemble
# 2022-06-22 10:23:57,142 [WARNING] /data/models/quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming
# 2022-06-22 10:23:57,143 [WARNING] /data/models/riva-trt-quartznet already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-quartznet
# 2022-06-22 10:23:57,143 [WARNING] /data/models/quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming
# 2022-06-22 10:23:57,143 [WARNING] /data/models/quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming
# 2022-06-22 10:23:57,143 [WARNING] /data/models/quartznet-asr-trt-ensemble-vad-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/quartznet-asr-trt-ensemble-vad-streaming
# 2022-06-22 10:23:59,593 [WARNING] /data/models/riva_tokenizer already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_tokenizer
# 2022-06-22 10:23:59,594 [WARNING] /data/models/riva-trt-riva_intent_weather-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_intent_weather-nn-bert-base-uncased
# 2022-06-22 10:23:59,594 [WARNING] /data/models/riva_label_tokens_weather already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_label_tokens_weather
# 2022-06-22 10:23:59,594 [WARNING] /data/models/riva_detokenize already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_detokenize
# 2022-06-22 10:23:59,594 [WARNING] /data/models/riva_intent_weather already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_intent_weather
# 2022-06-22 10:24:08,270 [WARNING] /data/models/quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline
# 2022-06-22 10:24:08,270 [WARNING] /data/models/riva-trt-quartznet already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-quartznet
# 2022-06-22 10:24:08,270 [WARNING] /data/models/quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline
# 2022-06-22 10:24:08,270 [WARNING] /data/models/quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline
# 2022-06-22 10:24:08,270 [WARNING] /data/models/quartznet-asr-trt-ensemble-vad-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/quartznet-asr-trt-ensemble-vad-streaming-offline
# 2022-06-22 10:24:10,313 [WARNING] /data/models/riva_tokenizer already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_tokenizer
# 2022-06-22 10:24:10,314 [WARNING] /data/models/riva-trt-riva_ner-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_ner-nn-bert-base-uncased
# 2022-06-22 10:24:10,314 [WARNING] /data/models/riva_ner_label_tokens already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_ner_label_tokens
# 2022-06-22 10:24:10,314 [WARNING] /data/models/riva_detokenize already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_detokenize
# 2022-06-22 10:24:10,314 [WARNING] /data/models/riva_ner already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_ner
# 2022-06-22 10:24:11,553 [WARNING] /data/models/riva_qa_preprocessor already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_qa_preprocessor
# 2022-06-22 10:24:11,553 [WARNING] /data/models/riva-trt-riva_qa-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_qa-nn-bert-base-uncased
# 2022-06-22 10:24:11,553 [WARNING] /data/models/riva_qa_postprocessor already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_qa_postprocessor
# 2022-06-22 10:24:11,553 [WARNING] /data/models/riva_qa already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_qa
# 2022-06-22 10:24:12,798 [WARNING] /data/models/riva_tokenizer already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_tokenizer
# 2022-06-22 10:24:12,798 [WARNING] /data/models/riva-trt-riva_text_classification_domain-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_text_classification_domain-nn-bert-base-uncased
# 2022-06-22 10:24:12,798 [WARNING] /data/models/riva_text_classification_domain already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_text_classification_domain
# 2022-06-22 10:24:14,045 [WARNING] /data/models/riva_tokenizer already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_tokenizer
# 2022-06-22 10:24:14,045 [WARNING] /data/models/riva-trt-riva_punctuation-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_punctuation-nn-bert-base-uncased
# 2022-06-22 10:24:14,045 [WARNING] /data/models/riva_punctuation_label_tokens_punct already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_punctuation_label_tokens_punct
# 2022-06-22 10:24:14,045 [WARNING] /data/models/riva_punctuation_label_tokens_cap already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_punctuation_label_tokens_cap
# 2022-06-22 10:24:14,045 [WARNING] /data/models/riva_punctuation_merge_labels already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_punctuation_merge_labels
# 2022-06-22 10:24:14,045 [WARNING] /data/models/riva_detokenize already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_detokenize
# 2022-06-22 10:24:14,046 [WARNING] /data/models/riva_punctuation_gen_output already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_punctuation_gen_output
# 2022-06-22 10:24:14,046 [WARNING] /data/models/riva_punctuation already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_punctuation
# + echo
#
# + echo 'Riva initialization complete. Run ./riva_start.sh to launch services.'
# Riva initialization complete. Run ./riva_start.sh to launch services.

# %%
# Start the Riva server
# !cd $RIVA_QS && bash riva_start.sh config.sh
# Out:
# Starting Riva Speech Services. This may take several minutes depending on the number of models deployed.
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Riva server is ready...

# %% [markdown]
# Riva ASR and NLP services are running when you get "Riva server is ready..." (about 40 seconds)

# %% [markdown]
# ## 6.2.3 Riva Available Services Check
#
# To check the exposed Riva services, execute the `docker logs riva-speech` command.

# %%
# !docker logs riva-speech
# Out:
# ==========================
# === Riva Speech Skills ===
# ==========================
#
# NVIDIA Release 21.07 (build 25292380)
#
# Copyright (c) 2018-2021, NVIDIA CORPORATION.  All rights reserved.
#
# Various files include modifications (c) NVIDIA CORPORATION.  All rights reserved.
# NVIDIA modifications are covered by the license terms that apply to the underlying
# project or file.
#
# NOTE: Legacy NVIDIA Driver detected.  Compatibility mode ENABLED.
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for the inference server.  NVIDIA recommends the use of the following flags:
#    nvidia-docker run --shm-size=1g --ulimit memlock=-1 --ulimit stack=67108864 ...
#
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:33.262959 74 metrics.cc:228] Collecting metrics for GPU 0: Tesla T4
# I0622 10:24:33.275503 74 onnxruntime.cc:1722] TRITONBACKEND_Initialize: onnxruntime
# I0622 10:24:33.275537 74 onnxruntime.cc:1732] Triton TRITONBACKEND API version: 1.0
# I0622 10:24:33.275542 74 onnxruntime.cc:1738] 'onnxruntime' TRITONBACKEND API version: 1.0
# I0622 10:24:33.470835 74 pinned_memory_manager.cc:206] Pinned memory pool is created at '0x7f6510000000' with size 268435456
# I0622 10:24:33.471241 74 cuda_memory_manager.cc:103] CUDA memory pool is created on device 0 with size 1000000000
# I0622 10:24:33.524430 74 model_repository_manager.cc:1066] loading: quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming:1
# I0622 10:24:33.624765 74 model_repository_manager.cc:1066] loading: denoiser:1
# I0622 10:24:33.625081 74 custom_backend.cc:198] Creating instance quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming_0_0_cpu on CPU using libtriton_riva_asr_decoder_cpu.so
# W:parameter_parser.cc:106: Parameter forerunner_start_offset_ms could not be set from parameters
# W:parameter_parser.cc:107: Default value will be used
# W:parameter_parser.cc:106: Parameter voc_string could not be set from parameters
# W:parameter_parser.cc:107: Default value will be used
# I0622 10:24:33.725114 74 model_repository_manager.cc:1066] loading: quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming:1
# I0622 10:24:33.725504 74 custom_backend.cc:201] Creating instance denoiser_0_0_gpu0 on GPU 0 (7.5) using libtriton_riva_tts_denoiser.so
# I0622 10:24:33.825478 74 model_repository_manager.cc:1066] loading: quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline:1
# I0622 10:24:33.826169 74 custom_backend.cc:201] Creating instance quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming_0_0_gpu0 on GPU 0 (7.5) using libtriton_riva_asr_features.so
# I0622 10:24:33.925878 74 model_repository_manager.cc:1066] loading: quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline:1
# I0622 10:24:33.926173 74 custom_backend.cc:198] Creating instance quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline_0_0_cpu on CPU using libtriton_riva_asr_decoder_cpu.so
# W:parameter_parser.cc:106: Parameter forerunner_start_offset_ms could not be set from parameters
# W:parameter_parser.cc:107: Default value will be used
# W:parameter_parser.cc:106: Parameter voc_string could not be set from parameters
# W:parameter_parser.cc:107: Default value will be used
# I0622 10:24:34.026465 74 model_repository_manager.cc:1066] loading: quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline:1
# I0622 10:24:34.027321 74 custom_backend.cc:201] Creating instance quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline_0_0_gpu0 on GPU 0 (7.5) using libtriton_riva_asr_features.so
# I0622 10:24:34.127031 74 model_repository_manager.cc:1066] loading: quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming:1
# I0622 10:24:34.127669 74 custom_backend.cc:198] Creating instance quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline_0_0_cpu on CPU using libtriton_riva_asr_vad.so
# I0622 10:24:34.137775 74 model_repository_manager.cc:1240] successfully loaded 'quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:34.227554 74 model_repository_manager.cc:1066] loading: riva-trt-quartznet:1
# I0622 10:24:34.228291 74 custom_backend.cc:198] Creating instance quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming_0_0_cpu on CPU using libtriton_riva_asr_vad.so
# I0622 10:24:34.237656 74 model_repository_manager.cc:1240] successfully loaded 'quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming' version 1
# I0622 10:24:34.328171 74 model_repository_manager.cc:1066] loading: riva-trt-riva_intent_weather-nn-bert-base-uncased:1
# I0622 10:24:34.428716 74 model_repository_manager.cc:1066] loading: riva-trt-riva_ner-nn-bert-base-uncased:1
# I0622 10:24:34.529338 74 model_repository_manager.cc:1066] loading: riva-trt-riva_punctuation-nn-bert-base-uncased:1
# I0622 10:24:34.629661 74 model_repository_manager.cc:1066] loading: riva-trt-riva_qa-nn-bert-base-uncased:1
# I0622 10:24:34.730150 74 model_repository_manager.cc:1066] loading: riva-trt-riva_text_classification_domain-nn-bert-base-uncased:1
# I0622 10:24:34.830413 74 model_repository_manager.cc:1066] loading: riva-trt-tacotron2_encoder:1
# I0622 10:24:34.931141 74 model_repository_manager.cc:1066] loading: riva-trt-waveglow:1
# I0622 10:24:35.038354 74 model_repository_manager.cc:1066] loading: riva_detokenize:1
# I0622 10:24:35.138860 74 model_repository_manager.cc:1066] loading: riva_label_tokens_weather:1
# I0622 10:24:35.143475 74 custom_backend.cc:198] Creating instance riva_detokenize_0_0_cpu on CPU using libtriton_riva_nlp_detokenizer.so
# I0622 10:24:35.145390 74 model_repository_manager.cc:1240] successfully loaded 'riva_detokenize' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:35.239569 74 model_repository_manager.cc:1066] loading: riva_ner_label_tokens:1
# I0622 10:24:35.242222 74 custom_backend.cc:198] Creating instance riva_label_tokens_weather_0_0_cpu on CPU using libtriton_riva_nlp_seqlabel.so
# I0622 10:24:35.252992 74 model_repository_manager.cc:1240] successfully loaded 'riva_label_tokens_weather' version 1
# I0622 10:24:35.340122 74 model_repository_manager.cc:1066] loading: riva_punctuation_gen_output:1
# I0622 10:24:35.344033 74 custom_backend.cc:198] Creating instance riva_ner_label_tokens_0_0_cpu on CPU using libtriton_riva_nlp_seqlabel.so
# I0622 10:24:35.355109 74 model_repository_manager.cc:1240] successfully loaded 'riva_ner_label_tokens' version 1
# I0622 10:24:35.440774 74 model_repository_manager.cc:1066] loading: riva_punctuation_label_tokens_cap:1
# I0622 10:24:35.459323 74 custom_backend.cc:198] Creating instance riva_punctuation_gen_output_0_0_cpu on CPU using libtriton_riva_nlp_punctuation.so
# I0622 10:24:35.490959 74 model_repository_manager.cc:1240] successfully loaded 'riva_punctuation_gen_output' version 1
# I0622 10:24:35.541190 74 model_repository_manager.cc:1066] loading: riva_punctuation_label_tokens_punct:1
# I0622 10:24:35.546659 74 custom_backend.cc:198] Creating instance riva_punctuation_label_tokens_cap_0_0_cpu on CPU using libtriton_riva_nlp_seqlabel.so
# I0622 10:24:35.558987 74 model_repository_manager.cc:1240] successfully loaded 'riva_punctuation_label_tokens_cap' version 1
# I0622 10:24:35.643216 74 model_repository_manager.cc:1066] loading: riva_punctuation_merge_labels:1
# I0622 10:24:35.647280 74 custom_backend.cc:198] Creating instance riva_punctuation_label_tokens_punct_0_0_cpu on CPU using libtriton_riva_nlp_seqlabel.so
# I0622 10:24:35.658990 74 model_repository_manager.cc:1240] successfully loaded 'riva_punctuation_label_tokens_punct' version 1
# I0622 10:24:35.743809 74 model_repository_manager.cc:1066] loading: riva_qa_postprocessor:1
# I0622 10:24:35.744352 74 custom_backend.cc:198] Creating instance riva_punctuation_merge_labels_0_0_cpu on CPU using libtriton_riva_nlp_labels.so
# I0622 10:24:35.756750 74 model_repository_manager.cc:1240] successfully loaded 'riva_punctuation_merge_labels' version 1
# I0622 10:24:35.844170 74 model_repository_manager.cc:1066] loading: riva_qa_preprocessor:1
# I0622 10:24:35.845043 74 custom_backend.cc:198] Creating instance riva_qa_postprocessor_0_0_cpu on CPU using libtriton_riva_nlp_qa.so
# I0622 10:24:35.865154 74 model_repository_manager.cc:1240] successfully loaded 'riva_qa_postprocessor' version 1
# I0622 10:24:35.944745 74 model_repository_manager.cc:1066] loading: riva_tokenizer:1
# I0622 10:24:35.945762 74 custom_backend.cc:198] Creating instance riva_qa_preprocessor_0_0_cpu on CPU using libtriton_riva_nlp_tokenizer.so
# I0622 10:24:35.995407 74 model_repository_manager.cc:1240] successfully loaded 'riva_qa_preprocessor' version 1
# I0622 10:24:36.045308 74 model_repository_manager.cc:1066] loading: tacotron2_decoder_postnet:1
# I0622 10:24:36.046077 74 custom_backend.cc:198] Creating instance riva_tokenizer_0_0_cpu on CPU using libtriton_riva_nlp_tokenizer.so
# I0622 10:24:36.069193 74 model_repository_manager.cc:1240] successfully loaded 'riva_tokenizer' version 1
# I0622 10:24:36.145907 74 model_repository_manager.cc:1066] loading: tts_preprocessor:1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:42.019409 74 tacotron-decoder-postnet.cc:802] TRITONBACKEND_ModelInitialize: tacotron2_decoder_postnet (version 1)
# I0622 10:24:42.020888 74 tts-preprocessor.cc:176] TRITONBACKEND_ModelInitialize: tts_preprocessor (version 1)
# I0622 10:24:42.021639 74 tacotron-decoder-postnet.cc:721] model configuration:
# {
#     "name": "tacotron2_decoder_postnet",
#     "platform": "",
#     "backend": "riva_tts_taco_postnet",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 8,
#     "input": [
#         {
#             "name": "input_decoder",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1,
#                 400,
#                 512
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false
#         },
#         {
#             "name": "input_processed_decoder",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 400,
#                 128,
#                 1,
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false
#         },
#         {
#             "name": "input_num_characters",
#             "data_type": "TYPE_INT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false
#         }
#     ],
#     "output": [
#         {
#             "name": "spectrogram_chunk",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 1,
#                 80,
#                 80
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "z",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 8,
#                 2656,
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "num_valid_samples",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "end_flag",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "priority": "PRIORITY_DEFAULT",
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "oldest": {
#             "max_candidate_sequences": 8,
#             "preferred_batch_size": [
#                 8
#             ],
#             "max_queue_delay_microseconds": 1000
#         },
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "END",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_END",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "CORRID",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_CORRID",
#                         "int32_false_true": [],
#                         "fp32_false_true": [],
#                         "data_type": "TYPE_UINT64"
#                     }
#                 ]
#             }
#         ]
#     },
#     "instance_group": [
#         {
#             "name": "tacotron2_decoder_postnet_0",
#             "kind": "KIND_GPU",
#             "count": 1,
#             "gpus": [
#                 0
#             ],
#             "profile": []
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "z_dim0": {
#             "string_value": "8"
#         },
#         "z_dim1": {
#             "string_value": "2656"
#         },
#         "tacotron_decoder_engine": {
#             "string_value": "/data/models/tacotron2_decoder_postnet/1/model.plan"
#         },
#         "num_mels": {
#             "string_value": "80"
#         },
#         "encoding_dimension": {
#             "string_value": "512"
#         },
#         "max_execution_batch_size": {
#             "string_value": "8"
#         },
#         "chunk_length": {
#             "string_value": "80"
#         },
#         "max_input_length": {
#             "string_value": "400"
#         },
#         "attention_dimension": {
#             "string_value": "128"
#         },
#         "num_samples_per_frame": {
#             "string_value": "256"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": true
#     }
# }
# W0622 10:24:42.021697 74 tts-preprocessor.cc:164] Parameter abbreviation_path is deprecated
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I0622 10:24:42.023182   136 preprocessor.cc:33] TTS character mapping loaded from /data/models/tts_preprocessor/1/mapping.txt
# I0622 10:24:42.023466   136 preprocessor.cc:49] TTS phonetic mapping loaded from /data/models/tts_preprocessor/1/cmudict.txt
# I0622 10:24:42.023653   136 preprocessor.cc:62] Abbreviation mapping loaded from /data/models/tts_preprocessor/1/abbr.txt
# I0622 10:24:42.023756   136 preprocessor.cc:72] TTS normalizer loaded from /opt/riva/tn_configs/sparrowhawk_configuration.ascii_proto
# I0622 10:24:42.035048 74 tacotron-decoder-postnet.cc:856] TRITONBACKEND_ModelInstanceInitialize: tacotron2_decoder_postnet_0 (device 0)
# I0622 10:24:42.129298 74 model_repository_manager.cc:1240] successfully loaded 'quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming' version 1
# I0622 10:24:42.141083 74 backend_model.cc:134] model configuration:
# {
#     "name": "tts_preprocessor",
#     "platform": "",
#     "backend": "riva_tts_preprocessor",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 8,
#     "input": [
#         {
#             "name": "input_string",
#             "data_type": "TYPE_STRING",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false
#         }
#     ],
#     "output": [
#         {
#             "name": "output",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 1,
#                 400
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "output_mask",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 1,
#                 400,
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "output_length",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "is_last_sentence",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "priority": "PRIORITY_DEFAULT",
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "oldest": {
#             "max_candidate_sequences": 8,
#             "preferred_batch_size": [
#                 8
#             ],
#             "max_queue_delay_microseconds": 100
#         },
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "END",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_END",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "CORRID",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_CORRID",
#                         "int32_false_true": [],
#                         "fp32_false_true": [],
#                         "data_type": "TYPE_UINT64"
#                     }
#                 ]
#             }
#         ]
#     },
#     "instance_group": [
#         {
#             "name": "tts_preprocessor_0",
#             "kind": "KIND_GPU",
#             "count": 1,
#             "gpus": [
#                 0
#             ],
#             "profile": []
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "max_input_length": {
#             "string_value": "400"
#         },
#         "abbreviations_path": {
#             "string_value": "/data/models/tts_preprocessor/1/abbr.txt"
#         },
#         "dictionary_path": {
#             "string_value": "/data/models/tts_preprocessor/1/cmudict.txt"
#         },
#         "mapping_path": {
#             "string_value": "/data/models/tts_preprocessor/1/mapping.txt"
#         },
#         "language": {
#             "string_value": "en-US"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": true
#     }
# }
# I0622 10:24:42.141256 74 tts-preprocessor.cc:178] TRITONBACKEND_ModelInstanceInitialize: tts_preprocessor_0 (device 0)
# I0622 10:24:42.142178 74 model_repository_manager.cc:1240] successfully loaded 'tts_preprocessor' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:42.530618 74 model_repository_manager.cc:1240] successfully loaded 'quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:49.654138 74 model_repository_manager.cc:1240] successfully loaded 'quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming' version 1
# I0622 10:24:49.655358 74 model_repository_manager.cc:1240] successfully loaded 'quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline' version 1
# I0622 10:24:49.655857 74 plan_backend.cc:384] Creating instance riva-trt-quartznet_0_0_gpu0 on GPU 0 (7.5) using model.plan
# I0622 10:24:49.765523 74 model_repository_manager.cc:1240] successfully loaded 'denoiser' version 1
# I0622 10:24:49.922614 74 plan_backend.cc:768] Created instance riva-trt-quartznet_0_0_gpu0 on GPU 0 with stream priority 0 and optimization profile default[0];
# I0622 10:24:49.924719 74 model_repository_manager.cc:1240] successfully loaded 'riva-trt-quartznet' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:51.246979 74 plan_backend.cc:384] Creating instance riva-trt-riva_intent_weather-nn-bert-base-uncased_0_0_gpu0 on GPU 0 (7.5) using model.plan
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:52.315634 74 model_repository_manager.cc:1240] successfully loaded 'tacotron2_decoder_postnet' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:52.624155 74 plan_backend.cc:768] Created instance riva-trt-riva_intent_weather-nn-bert-base-uncased_0_0_gpu0 on GPU 0 with stream priority 0 and optimization profile default[0];
# I0622 10:24:52.637773 74 model_repository_manager.cc:1240] successfully loaded 'riva-trt-riva_intent_weather-nn-bert-base-uncased' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:53.935948 74 plan_backend.cc:384] Creating instance riva-trt-riva_qa-nn-bert-base-uncased_0_0_gpu0 on GPU 0 (7.5) using model.plan
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:55.315130 74 plan_backend.cc:768] Created instance riva-trt-riva_qa-nn-bert-base-uncased_0_0_gpu0 on GPU 0 with stream priority 0 and optimization profile default[0];
# I0622 10:24:55.326407 74 model_repository_manager.cc:1240] successfully loaded 'riva-trt-riva_qa-nn-bert-base-uncased' version 1
# I0622 10:24:55.401174 74 plan_backend.cc:384] Creating instance riva-trt-tacotron2_encoder_0_0_gpu0 on GPU 0 (7.5) using model.plan
# I0622 10:24:55.414396 74 plan_backend.cc:772] Created instance riva-trt-tacotron2_encoder_0_0_gpu0 on GPU 0 with stream priority 0
# I0622 10:24:55.422553 74 model_repository_manager.cc:1240] successfully loaded 'riva-trt-tacotron2_encoder' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:56.731184 74 plan_backend.cc:384] Creating instance riva-trt-riva_punctuation-nn-bert-base-uncased_0_0_gpu0 on GPU 0 (7.5) using model.plan
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:58.090397 74 plan_backend.cc:768] Created instance riva-trt-riva_punctuation-nn-bert-base-uncased_0_0_gpu0 on GPU 0 with stream priority 0 and optimization profile default[0];
# I0622 10:24:58.100198 74 model_repository_manager.cc:1240] successfully loaded 'riva-trt-riva_punctuation-nn-bert-base-uncased' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:24:59.422126 74 plan_backend.cc:384] Creating instance riva-trt-riva_ner-nn-bert-base-uncased_0_0_gpu0 on GPU 0 (7.5) using model.plan
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:25:00.796607 74 plan_backend.cc:768] Created instance riva-trt-riva_ner-nn-bert-base-uncased_0_0_gpu0 on GPU 0 with stream priority 0 and optimization profile default[0];
# I0622 10:25:00.806658 74 model_repository_manager.cc:1240] successfully loaded 'riva-trt-riva_ner-nn-bert-base-uncased' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:25:02.115401 74 plan_backend.cc:384] Creating instance riva-trt-riva_text_classification_domain-nn-bert-base-uncased_0_0_gpu0 on GPU 0 (7.5) using model.plan
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:25:03.479441 74 plan_backend.cc:768] Created instance riva-trt-riva_text_classification_domain-nn-bert-base-uncased_0_0_gpu0 on GPU 0 with stream priority 0 and optimization profile default[0];
# I0622 10:25:03.492958 74 model_repository_manager.cc:1240] successfully loaded 'riva-trt-riva_text_classification_domain-nn-bert-base-uncased' version 1
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:25:04.608959 74 plan_backend.cc:384] Creating instance riva-trt-waveglow_0_0_gpu0 on GPU 0 (7.5) using model.plan
#   > Riva waiting for Triton server to load all models...retrying in 1 second
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0622 10:25:05.702066 74 plan_backend.cc:768] Created instance riva-trt-waveglow_0_0_gpu0 on GPU 0 with stream priority 0 and optimization profile default[0];
# I0622 10:25:05.722751 74 model_repository_manager.cc:1240] successfully loaded 'riva-trt-waveglow' version 1
# I0622 10:25:05.724428 74 model_repository_manager.cc:1066] loading: quartznet-asr-trt-ensemble-vad-streaming:1
# I0622 10:25:05.824656 74 model_repository_manager.cc:1066] loading: quartznet-asr-trt-ensemble-vad-streaming-offline:1
# I0622 10:25:05.924986 74 model_repository_manager.cc:1066] loading: riva_intent_weather:1
# I0622 10:25:06.025308 74 model_repository_manager.cc:1066] loading: riva_ner:1
# I0622 10:25:06.125653 74 model_repository_manager.cc:1066] loading: riva_punctuation:1
# I0622 10:25:06.225965 74 model_repository_manager.cc:1066] loading: riva_qa:1
# I0622 10:25:06.326236 74 model_repository_manager.cc:1066] loading: riva_text_classification_domain:1
# I0622 10:25:06.426513 74 model_repository_manager.cc:1066] loading: tacotron2_ensemble:1
# I0622 10:25:06.427154 74 model_repository_manager.cc:1240] successfully loaded 'riva_text_classification_domain' version 1
# I0622 10:25:06.526852 74 model_repository_manager.cc:1240] successfully loaded 'riva_punctuation' version 1
# I0622 10:25:06.526893 74 model_repository_manager.cc:1240] successfully loaded 'riva_qa' version 1
# I0622 10:25:06.526919 74 model_repository_manager.cc:1240] successfully loaded 'riva_ner' version 1
# I0622 10:25:06.526852 74 model_repository_manager.cc:1240] successfully loaded 'quartznet-asr-trt-ensemble-vad-streaming' version 1
# I0622 10:25:06.527179 74 model_repository_manager.cc:1240] successfully loaded 'riva_intent_weather' version 1I0622 10:25:06.527190 74 model_repository_manager.cc:1240] successfully loaded 'tacotron2_ensemble' version 1
#
# I0622 10:25:06.527284 74 model_repository_manager.cc:1240] successfully loaded 'quartznet-asr-trt-ensemble-vad-streaming-offline' version 1
# I0622 10:25:06.527489 74 server.cc:504]
# +------------------+------+
# | Repository Agent | Path |
# +------------------+------+
# +------------------+------+
#
# I0622 10:25:06.527543 74 server.cc:543]
# +-----------------------+-------------------------------------------------------------------------------------+--------+
# | Backend               | Path                                                                                | Config |
# +-----------------------+-------------------------------------------------------------------------------------+--------+
# | tensorrt              | <built-in>                                                                          | {}     |
# | onnxruntime           | /opt/tritonserver/backends/onnxruntime/libtriton_onnxruntime.so                     | {}     |
# | riva_tts_preprocessor | /opt/tritonserver/backends/riva_tts_preprocessor/libtriton_riva_tts_preprocessor.so | {}     |
# | riva_tts_taco_postnet | /opt/tritonserver/backends/riva_tts_taco_postnet/libtriton_riva_tts_taco_postnet.so | {}     |
# +-----------------------+-------------------------------------------------------------------------------------+--------+
#
# I0622 10:25:06.527714 74 server.cc:586]
# +------------------------------------------------------------------------------------------------+---------+--------+
# | Model                                                                                          | Version | Status |
# +------------------------------------------------------------------------------------------------+---------+--------+
# | denoiser                                                                                       | 1       | READY  |
# | quartznet-asr-trt-ensemble-vad-streaming                                                       | 1       | READY  |
# | quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming                             | 1       | READY  |
# | quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming                           | 1       | READY  |
# | quartznet-asr-trt-ensemble-vad-streaming-offline                                               | 1       | READY  |
# | quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline             | 1       | READY  |
# | quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline           | 1       | READY  |
# | quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline | 1       | READY  |
# | quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming                 | 1       | READY  |
# | riva-trt-quartznet                                                                             | 1       | READY  |
# | riva-trt-riva_intent_weather-nn-bert-base-uncased                                              | 1       | READY  |
# | riva-trt-riva_ner-nn-bert-base-uncased                                                         | 1       | READY  |
# | riva-trt-riva_punctuation-nn-bert-base-uncased                                                 | 1       | READY  |
# | riva-trt-riva_qa-nn-bert-base-uncased                                                          | 1       | READY  |
# | riva-trt-riva_text_classification_domain-nn-bert-base-uncased                                  | 1       | READY  |
# | riva-trt-tacotron2_encoder                                                                     | 1       | READY  |
# | riva-trt-waveglow                                                                              | 1       | READY  |
# | riva_detokenize                                                                                | 1       | READY  |
# | riva_intent_weather                                                                            | 1       | READY  |
# | riva_label_tokens_weather                                                                      | 1       | READY  |
# | riva_ner                                                                                       | 1       | READY  |
# | riva_ner_label_tokens                                                                          | 1       | READY  |
# | riva_punctuation                                                                               | 1       | READY  |
# | riva_punctuation_gen_output                                                                    | 1       | READY  |
# | riva_punctuation_label_tokens_cap                                                              | 1       | READY  |
# | riva_punctuation_label_tokens_punct                                                            | 1       | READY  |
# | riva_punctuation_merge_labels                                                                  | 1       | READY  |
# | riva_qa                                                                                        | 1       | READY  |
# | riva_qa_postprocessor                                                                          | 1       | READY  |
# | riva_qa_preprocessor                                                                           | 1       | READY  |
# | riva_text_classification_domain                                                                | 1       | READY  |
# | riva_tokenizer                                                                                 | 1       | READY  |
# | tacotron2_decoder_postnet                                                                      | 1       | READY  |
# | tacotron2_ensemble                                                                             | 1       | READY  |
# | tts_preprocessor                                                                               | 1       | READY  |
# +------------------------------------------------------------------------------------------------+---------+--------+
#
# I0622 10:25:06.527839 74 tritonserver.cc:1658]
# +----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Option                           | Value                                                                                                                                                                                  |
# +----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | server_id                        | triton                                                                                                                                                                                 |
# | server_version                   | 2.9.0                                                                                                                                                                                  |
# | server_extensions                | classification sequence model_repository model_repository(unload_dependents) schedule_policy model_configuration system_shared_memory cuda_shared_memory binary_tensor_data statistics |
# | model_repository_path[0]         | /data/models                                                                                                                                                                           |
# | model_control_mode               | MODE_NONE                                                                                                                                                                              |
# | strict_model_config              | 1                                                                                                                                                                                      |
# | pinned_memory_pool_byte_size     | 268435456                                                                                                                                                                              |
# | cuda_memory_pool_byte_size{0}    | 1000000000                                                                                                                                                                             |
# | min_supported_compute_capability | 6.0                                                                                                                                                                                    |
# | strict_readiness                 | 1                                                                                                                                                                                      |
# | exit_timeout                     | 30                                                                                                                                                                                     |
# +----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# I0622 10:25:06.539005 74 grpc_server.cc:4028] Started GRPCInferenceService at 0.0.0.0:8001
# I0622 10:25:06.540302 74 http_server.cc:2761] Started HTTPService at 0.0.0.0:8000
# I0622 10:25:06.582056 74 http_server.cc:2780] Started Metrics Service at 0.0.0.0:8002
#   > Triton server is ready...
# I0622 10:25:06.641357   325 grpc_health.cc:27] RivaHealthService initialized with server: localhost:8001
# I0622 10:25:06.641410   325 grpc_riva_asr.cc:148] Setting uri for ASRServiceImpl
# I0622 10:25:06.641415   325 grpc_riva_asr.cc:149] Initializing different models
# I0622 10:25:06.641767   325 model_registry.cc:36] RivaModelRegistry initialized with server: localhost:8001
# I0622 10:25:06.644153   325 model_registry.cc:65] Server Name: triton, Server version: 2.9.0
# I0622 10:25:06.644547   325 model_registry.cc:86] Our model repository has a total of: 35 models
# I0622 10:25:06.644562   325 model_registry.cc:91] Model names: denoiser, Model version: 1
# I0622 10:25:06.648510   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming, Model version: 1
# I0622 10:25:06.649377   325 model_registry.cc:104] 'Successfully registering quartznet-asr-trt-ensemble-vad-streaming'
# I0622 10:25:06.649431   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming, Model version: 1
# I0622 10:25:06.650378   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming, Model version: 1
# I0622 10:25:06.651360   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline, Model version: 1
# I0622 10:25:06.652205   325 model_registry.cc:104] 'Successfully registering quartznet-asr-trt-ensemble-vad-streaming-offline'
# I0622 10:25:06.652254   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline, Model version: 1
# I0622 10:25:06.653110   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline, Model version: 1
# I0622 10:25:06.653981   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline, Model version: 1
# I0622 10:25:06.654629   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming, Model version: 1
# I0622 10:25:06.655427   325 model_registry.cc:91] Model names: riva-trt-quartznet, Model version: 1
# I0622 10:25:06.655985   325 model_registry.cc:91] Model names: riva-trt-riva_intent_weather-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.656538   325 model_registry.cc:91] Model names: riva-trt-riva_ner-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.657138   325 model_registry.cc:91] Model names: riva-trt-riva_punctuation-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.657716   325 model_registry.cc:91] Model names: riva-trt-riva_qa-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.658313   325 model_registry.cc:91] Model names: riva-trt-riva_text_classification_domain-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.658951   325 model_registry.cc:91] Model names: riva-trt-tacotron2_encoder, Model version: 1
# I0622 10:25:06.659574   325 model_registry.cc:91] Model names: riva-trt-waveglow, Model version: 1
# I0622 10:25:06.660288   325 model_registry.cc:91] Model names: riva_detokenize, Model version: 1
# I0622 10:25:06.660908   325 model_registry.cc:91] Model names: riva_intent_weather, Model version: 1
# I0622 10:25:06.661661   325 model_registry.cc:91] Model names: riva_label_tokens_weather, Model version: 1
# I0622 10:25:06.662201   325 model_registry.cc:91] Model names: riva_ner, Model version: 1
# I0622 10:25:06.662961   325 model_registry.cc:91] Model names: riva_ner_label_tokens, Model version: 1
# I0622 10:25:06.663508   325 model_registry.cc:91] Model names: riva_punctuation, Model version: 1
# I0622 10:25:06.664247   325 model_registry.cc:91] Model names: riva_punctuation_gen_output, Model version: 1
# I0622 10:25:06.664813   325 model_registry.cc:91] Model names: riva_punctuation_label_tokens_cap, Model version: 1
# I0622 10:25:06.665338   325 model_registry.cc:91] Model names: riva_punctuation_label_tokens_punct, Model version: 1
# I0622 10:25:06.665861   325 model_registry.cc:91] Model names: riva_punctuation_merge_labels, Model version: 1
# I0622 10:25:06.666414   325 model_registry.cc:91] Model names: riva_qa, Model version: 1
# I0622 10:25:06.667207   325 model_registry.cc:91] Model names: riva_qa_postprocessor, Model version: 1
# I0622 10:25:06.667861   325 model_registry.cc:91] Model names: riva_qa_preprocessor, Model version: 1
# I0622 10:25:06.668584   325 model_registry.cc:91] Model names: riva_text_classification_domain, Model version: 1
# I0622 10:25:06.669188   325 model_registry.cc:91] Model names: riva_tokenizer, Model version: 1
# I0622 10:25:06.669821   325 model_registry.cc:91] Model names: tacotron2_decoder_postnet, Model version: 1
# I0622 10:25:06.670648   325 model_registry.cc:91] Model names: tacotron2_ensemble, Model version: 1
# I0622 10:25:06.671427   325 model_registry.cc:91] Model names: tts_preprocessor, Model version: 1
# I0622 10:25:06.672214   325 model_registry.cc:109] Successfully registered: 2 models.
# I0622 10:25:06.672231   325 client.cc:38] RivaLanguageUnderstandingClient initialized with server: localhost:8001
# I0622 10:25:06.672606   325 client.cc:54] Our model repository has: 35 models.
# W0622 10:25:06.674178   325 client.cc:78] Registration of 'quartznet-asr-trt-ensemble-vad-streaming' failed with unknown service type
# W0622 10:25:06.676662   325 client.cc:78] Registration of 'quartznet-asr-trt-ensemble-vad-streaming-offline' failed with unknown service type
# I0622 10:25:06.684965   325 client.cc:72] Registering 'riva_intent_weather' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyTokens'
# I0622 10:25:06.686161   325 client.cc:72] Registering 'riva_ner' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyTokens'
# I0622 10:25:06.687434   325 client.cc:72] Registering 'riva_punctuation' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/TransformText'
# I0622 10:25:06.690263   325 client.cc:72] Registering 'riva_qa' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyTokens'
# I0622 10:25:06.692154   325 client.cc:72] Registering 'riva_text_classification_domain' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyText'
# W0622 10:25:06.694173   325 client.cc:78] Registration of 'tacotron2_ensemble' failed with unknown service type
# I0622 10:25:06.695134   325 grpc_riva_asr.cc:177] Seeding RNG used for correlation id with time: 1655893506
# I0622 10:25:06.752290   325 grpc_riva_asr.cc:148] Setting uri for ASRServiceImpl
# I0622 10:25:06.752313   325 grpc_riva_asr.cc:149] Initializing different models
# I0622 10:25:06.752326   325 model_registry.cc:36] RivaModelRegistry initialized with server: localhost:8001
# I0622 10:25:06.752785   325 model_registry.cc:65] Server Name: triton, Server version: 2.9.0
# I0622 10:25:06.753162   325 model_registry.cc:86] Our model repository has a total of: 35 models
# I0622 10:25:06.753173   325 model_registry.cc:91] Model names: denoiser, Model version: 1
# I0622 10:25:06.754029   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming, Model version: 1
# I0622 10:25:06.755007   325 model_registry.cc:104] 'Successfully registering quartznet-asr-trt-ensemble-vad-streaming'
# I0622 10:25:06.755050   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming, Model version: 1
# I0622 10:25:06.756000   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming, Model version: 1
# I0622 10:25:06.756896   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline, Model version: 1
# I0622 10:25:06.757745   325 model_registry.cc:104] 'Successfully registering quartznet-asr-trt-ensemble-vad-streaming-offline'
# I0622 10:25:06.757793   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline, Model version: 1
# I0622 10:25:06.758652   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline, Model version: 1
# I0622 10:25:06.759624   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline, Model version: 1
# I0622 10:25:06.760350   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming, Model version: 1
# I0622 10:25:06.761065   325 model_registry.cc:91] Model names: riva-trt-quartznet, Model version: 1
# I0622 10:25:06.761680   325 model_registry.cc:91] Model names: riva-trt-riva_intent_weather-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.762308   325 model_registry.cc:91] Model names: riva-trt-riva_ner-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.762969   325 model_registry.cc:91] Model names: riva-trt-riva_punctuation-nn-bert-base-uncased, Model version: 1
# ...
# I0622 10:25:06.868268   325 model_registry.cc:91] Model names: riva_ner, Model version: 1
# I0622 10:25:06.869010   325 model_registry.cc:104] 'Successfully registering riva_ner'
# I0622 10:25:06.869052   325 model_registry.cc:91] Model names: riva_ner_label_tokens, Model version: 1
# I0622 10:25:06.869577   325 model_registry.cc:91] Model names: riva_punctuation, Model version: 1
# I0622 10:25:06.870311   325 model_registry.cc:104] 'Successfully registering riva_punctuation'
# I0622 10:25:06.870352   325 model_registry.cc:91] Model names: riva_punctuation_gen_output, Model version: 1
# I0622 10:25:06.870997   325 model_registry.cc:91] Model names: riva_punctuation_label_tokens_cap, Model version: 1
# I0622 10:25:06.871582   325 model_registry.cc:91] Model names: riva_punctuation_label_tokens_punct, Model version: 1
# I0622 10:25:06.872151   325 model_registry.cc:91] Model names: riva_punctuation_merge_labels, Model version: 1
# I0622 10:25:06.872655   325 model_registry.cc:91] Model names: riva_qa, Model version: 1
# I0622 10:25:06.873379   325 model_registry.cc:104] 'Successfully registering riva_qa'
# I0622 10:25:06.873415   325 model_registry.cc:91] Model names: riva_qa_postprocessor, Model version: 1
# I0622 10:25:06.874047   325 model_registry.cc:91] Model names: riva_qa_preprocessor, Model version: 1
# I0622 10:25:06.874696   325 model_registry.cc:91] Model names: riva_text_classification_domain, Model version: 1
# I0622 10:25:06.875353   325 model_registry.cc:104] 'Successfully registering riva_text_classification_domain'
# I0622 10:25:06.875385   325 model_registry.cc:91] Model names: riva_tokenizer, Model version: 1
# I0622 10:25:06.876001   325 model_registry.cc:91] Model names: tacotron2_decoder_postnet, Model version: 1
# I0622 10:25:06.876772   325 model_registry.cc:91] Model names: tacotron2_ensemble, Model version: 1
# I0622 10:25:06.877413   325 model_registry.cc:104] 'Successfully registering tacotron2_ensemble'
# I0622 10:25:06.877446   325 model_registry.cc:91] Model names: tts_preprocessor, Model version: 1
# I0622 10:25:06.878203   325 model_registry.cc:109] Successfully registered: 8 models.
# I0622 10:25:06.878235   325 grpc_riva_nlp.cc:33] NLPService GRPC service started
# I0622 10:25:06.878243   325 client.cc:38] RivaLanguageUnderstandingClient initialized with server: localhost:8001
# I0622 10:25:06.878597   325 client.cc:54] Our model repository has: 35 models.
# W0622 10:25:06.880182   325 client.cc:78] Registration of 'quartznet-asr-trt-ensemble-vad-streaming' failed with unknown service type
# W0622 10:25:06.882503   325 client.cc:78] Registration of 'quartznet-asr-trt-ensemble-vad-streaming-offline' failed with unknown service type
# I0622 10:25:06.890767   325 client.cc:72] Registering 'riva_intent_weather' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyTokens'
# I0622 10:25:06.892011   325 client.cc:72] Registering 'riva_ner' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyTokens'
# I0622 10:25:06.893188   325 client.cc:72] Registering 'riva_punctuation' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/TransformText'
# I0622 10:25:06.895865   325 client.cc:72] Registering 'riva_qa' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyTokens'
# I0622 10:25:06.897702   325 client.cc:72] Registering 'riva_text_classification_domain' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyText'
# W0622 10:25:06.899745   325 client.cc:78] Registration of 'tacotron2_ensemble' failed with unknown service type
# I0622 10:25:06.900552   325 model_registry.cc:36] RivaModelRegistry initialized with server: localhost:8001
# I0622 10:25:06.900879   325 model_registry.cc:65] Server Name: triton, Server version: 2.9.0
# I0622 10:25:06.901234   325 model_registry.cc:86] Our model repository has a total of: 35 models
# I0622 10:25:06.901244   325 model_registry.cc:91] Model names: denoiser, Model version: 1
# I0622 10:25:06.901971   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming, Model version: 1
# I0622 10:25:06.902858   325 model_registry.cc:104] 'Successfully registering quartznet-asr-trt-ensemble-vad-streaming'
# I0622 10:25:06.902901   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming, Model version: 1
# I0622 10:25:06.903767   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming, Model version: 1
# I0622 10:25:06.904603   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline, Model version: 1
# I0622 10:25:06.905380   325 model_registry.cc:104] 'Successfully registering quartznet-asr-trt-ensemble-vad-streaming-offline'
# I0622 10:25:06.905419   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline, Model version: 1
# I0622 10:25:06.906281   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline, Model version: 1
# I0622 10:25:06.907210   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline, Model version: 1
# I0622 10:25:06.907963   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming, Model version: 1
# I0622 10:25:06.908715   325 model_registry.cc:91] Model names: riva-trt-quartznet, Model version: 1
# I0622 10:25:06.909281   325 model_registry.cc:91] Model names: riva-trt-riva_intent_weather-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.909924   325 model_registry.cc:91] Model names: riva-trt-riva_ner-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.910499   325 model_registry.cc:91] Model names: riva-trt-riva_punctuation-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.911204   325 model_registry.cc:91] Model names: riva-trt-riva_qa-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.911808   325 model_registry.cc:91] Model names: riva-trt-riva_text_classification_domain-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.912417   325 model_registry.cc:91] Model names: riva-trt-tacotron2_encoder, Model version: 1
# I0622 10:25:06.913029   325 model_registry.cc:91] Model names: riva-trt-waveglow, Model version: 1
# I0622 10:25:06.913792   325 model_registry.cc:91] Model names: riva_detokenize, Model version: 1
# I0622 10:25:06.914422   325 model_registry.cc:91] Model names: riva_intent_weather, Model version: 1
# I0622 10:25:06.915225   325 model_registry.cc:104] 'Successfully registering riva_intent_weather'
# I0622 10:25:06.915271   325 model_registry.cc:91] Model names: riva_label_tokens_weather, Model version: 1
# I0622 10:25:06.915812   325 model_registry.cc:91] Model names: riva_ner, Model version: 1
# I0622 10:25:06.916558   325 model_registry.cc:104] 'Successfully registering riva_ner'
# I0622 10:25:06.916596   325 model_registry.cc:91] Model names: riva_ner_label_tokens, Model version: 1
# I0622 10:25:06.917105   325 model_registry.cc:91] Model names: riva_punctuation, Model version: 1
# I0622 10:25:06.917824   325 model_registry.cc:104] 'Successfully registering riva_punctuation'
# I0622 10:25:06.917866   325 model_registry.cc:91] Model names: riva_punctuation_gen_output, Model version: 1
# I0622 10:25:06.918409   325 model_registry.cc:91] Model names: riva_punctuation_label_tokens_cap, Model version: 1
# I0622 10:25:06.919016   325 model_registry.cc:91] Model names: riva_punctuation_label_tokens_punct, Model version: 1
# I0622 10:25:06.919580   325 model_registry.cc:91] Model names: riva_punctuation_merge_labels, Model version: 1
# I0622 10:25:06.920147   325 model_registry.cc:91] Model names: riva_qa, Model version: 1
# I0622 10:25:06.920857   325 model_registry.cc:104] 'Successfully registering riva_qa'
# I0622 10:25:06.920897   325 model_registry.cc:91] Model names: riva_qa_postprocessor, Model version: 1
# I0622 10:25:06.921473   325 model_registry.cc:91] Model names: riva_qa_preprocessor, Model version: 1
# I0622 10:25:06.922127   325 model_registry.cc:91] Model names: riva_text_classification_domain, Model version: 1
# I0622 10:25:06.922714   325 model_registry.cc:104] 'Successfully registering riva_text_classification_domain'
# I0622 10:25:06.922761   325 model_registry.cc:91] Model names: riva_tokenizer, Model version: 1
# I0622 10:25:06.923388   325 model_registry.cc:91] Model names: tacotron2_decoder_postnet, Model version: 1
# I0622 10:25:06.924218   325 model_registry.cc:91] Model names: tacotron2_ensemble, Model version: 1
# I0622 10:25:06.924886   325 model_registry.cc:104] 'Successfully registering tacotron2_ensemble'
# I0622 10:25:06.924923   325 model_registry.cc:91] Model names: tts_preprocessor, Model version: 1
# I0622 10:25:06.925701   325 model_registry.cc:109] Successfully registered: 8 models.
# I0622 10:25:06.925725   325 grpc_riva_nlp.cc:33] NLPService GRPC service started
# I0622 10:25:06.925734   325 client.cc:38] RivaLanguageUnderstandingClient initialized with server: localhost:8001
# I0622 10:25:06.926079   325 client.cc:54] Our model repository has: 35 models.
# W0622 10:25:06.927585   325 client.cc:78] Registration of 'quartznet-asr-trt-ensemble-vad-streaming' failed with unknown service type
# W0622 10:25:06.929929   325 client.cc:78] Registration of 'quartznet-asr-trt-ensemble-vad-streaming-offline' failed with unknown service type
# I0622 10:25:06.938091   325 client.cc:72] Registering 'riva_intent_weather' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyTokens'
# I0622 10:25:06.939327   325 client.cc:72] Registering 'riva_ner' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyTokens'
# I0622 10:25:06.940536   325 client.cc:72] Registering 'riva_punctuation' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/TransformText'
# I0622 10:25:06.943207   325 client.cc:72] Registering 'riva_qa' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyTokens'
# I0622 10:25:06.944929   325 client.cc:72] Registering 'riva_text_classification_domain' with service '/nvidia.riva.nlp.RivaLanguageUnderstanding/ClassifyText'
# W0622 10:25:06.946887   325 client.cc:78] Registration of 'tacotron2_ensemble' failed with unknown service type
# I0622 10:25:06.947666   325 model_registry.cc:36] RivaModelRegistry initialized with server: localhost:8001
# I0622 10:25:06.947993   325 model_registry.cc:65] Server Name: triton, Server version: 2.9.0
# I0622 10:25:06.948319   325 model_registry.cc:86] Our model repository has a total of: 35 models
# I0622 10:25:06.948328   325 model_registry.cc:91] Model names: denoiser, Model version: 1
# I0622 10:25:06.949030   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming, Model version: 1
# I0622 10:25:06.949806   325 model_registry.cc:104] 'Successfully registering quartznet-asr-trt-ensemble-vad-streaming'
# I0622 10:25:06.949848   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-ctc-decoder-cpu-streaming, Model version: 1
# I0622 10:25:06.950664   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-feature-extractor-streaming, Model version: 1
# I0622 10:25:06.951614   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline, Model version: 1
# I0622 10:25:06.952456   325 model_registry.cc:104] 'Successfully registering quartznet-asr-trt-ensemble-vad-streaming-offline'
# I0622 10:25:06.952502   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-ctc-decoder-cpu-streaming-offline, Model version: 1
# I0622 10:25:06.953349   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-feature-extractor-streaming-offline, Model version: 1
# I0622 10:25:06.954221   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-offline-voice-activity-detector-ctc-streaming-offline, Model version: 1
# I0622 10:25:06.954943   325 model_registry.cc:91] Model names: quartznet-asr-trt-ensemble-vad-streaming-voice-activity-detector-ctc-streaming, Model version: 1
# I0622 10:25:06.955636   325 model_registry.cc:91] Model names: riva-trt-quartznet, Model version: 1
# I0622 10:25:06.956199   325 model_registry.cc:91] Model names: riva-trt-riva_intent_weather-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.956764   325 model_registry.cc:91] Model names: riva-trt-riva_ner-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.957316   325 model_registry.cc:91] Model names: riva-trt-riva_punctuation-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.957886   325 model_registry.cc:91] Model names: riva-trt-riva_qa-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.958439   325 model_registry.cc:91] Model names: riva-trt-riva_text_classification_domain-nn-bert-base-uncased, Model version: 1
# I0622 10:25:06.959053   325 model_registry.cc:91] Model names: riva-trt-tacotron2_encoder, Model version: 1
# I0622 10:25:06.959650   325 model_registry.cc:91] Model names: riva-trt-waveglow, Model version: 1
# I0622 10:25:06.960284   325 model_registry.cc:91] Model names: riva_detokenize, Model version: 1
# I0622 10:25:06.960839   325 model_registry.cc:91] Model names: riva_intent_weather, Model version: 1
# I0622 10:25:06.961532   325 model_registry.cc:104] 'Successfully registering riva_intent_weather'
# I0622 10:25:06.961571   325 model_registry.cc:91] Model names: riva_label_tokens_weather, Model version: 1
# I0622 10:25:06.962141   325 model_registry.cc:91] Model names: riva_ner, Model version: 1
# I0622 10:25:06.962894   325 model_registry.cc:104] 'Successfully registering riva_ner'
# I0622 10:25:06.962949   325 model_registry.cc:91] Model names: riva_ner_label_tokens, Model version: 1
# I0622 10:25:06.963488   325 model_registry.cc:91] Model names: riva_punctuation, Model version: 1
# I0622 10:25:06.964257   325 model_registry.cc:104] 'Successfully registering riva_punctuation'
# I0622 10:25:06.964310   325 model_registry.cc:91] Model names: riva_punctuation_gen_output, Model version: 1
# I0622 10:25:06.964900   325 model_registry.cc:91] Model names: riva_punctuation_label_tokens_cap, Model version: 1
# I0622 10:25:06.965468   325 model_registry.cc:91] Model names: riva_punctuation_label_tokens_punct, Model version: 1
# I0622 10:25:06.966035   325 model_registry.cc:91] Model names: riva_punctuation_merge_labels, Model version: 1
# I0622 10:25:06.966634   325 model_registry.cc:91] Model names: riva_qa, Model version: 1
# I0622 10:25:06.967412   325 model_registry.cc:104] 'Successfully registering riva_qa'
# I0622 10:25:06.967447   325 model_registry.cc:91] Model names: riva_qa_postprocessor, Model version: 1
# I0622 10:25:06.968066   325 model_registry.cc:91] Model names: riva_qa_preprocessor, Model version: 1
# I0622 10:25:06.968685   325 model_registry.cc:91] Model names: riva_text_classification_domain, Model version: 1
# I0622 10:25:06.969225   325 model_registry.cc:104] 'Successfully registering riva_text_classification_domain'
# I0622 10:25:06.969249   325 model_registry.cc:91] Model names: riva_tokenizer, Model version: 1
# I0622 10:25:06.969853   325 model_registry.cc:91] Model names: tacotron2_decoder_postnet, Model version: 1
# I0622 10:25:06.970623   325 model_registry.cc:91] Model names: tacotron2_ensemble, Model version: 1
# I0622 10:25:06.971316   325 model_registry.cc:104] 'Successfully registering tacotron2_ensemble'
# I0622 10:25:06.971349   325 model_registry.cc:91] Model names: tts_preprocessor, Model version: 1
# I0622 10:25:06.972101   325 model_registry.cc:109] Successfully registered: 8 models.
# I0622 10:25:06.972119   325 grpc_riva_nlp.cc:33] NLPService GRPC service started
# I0622 10:25:06.972364   325 riva_server.cc:91] NLP Service connected to Triton at localhost:8001
# I0622 10:25:06.972375   325 riva_server.cc:93] ASR Service connected to Triton at localhost:8001
# I0622 10:25:06.972378   325 riva_server.cc:96] Riva Conversational AI Server listening on 0.0.0.0:50051

# %% [markdown]
# ---
# # 6.3 Run the Application Service

# %% [markdown]
# In the app, we use Riva for two purposes:
# 1. To get a streaming transcript of the conversation using ASR
# 1. To tag key phrases (named entities) in that transcript with NER.
#
# The flow is:
# - Extract an audio stream from the client and pass that audio to the Node.js server (step 1).
# - The Node.js server calls Riva services, using gRPC, to get transcripts (step 2) and named entities (step 4)
# - The Node.js server sends the results back to the client (step 3 and 5).
# - The client can then render the transcripts in the browser and pass the transcripts over the peer-to-peer connection so that both users can see the whole conversation.
#
# Riva Contact uses environment variables to manage its configuration parameters. These are kept in a configuration file, [env.txt](contact-app/env.txt). In your own project, you may wish to change some of these configurations.  For example, the NER entity list would change if you were to deploy your own custom domain-specific NER model.

# %% [markdown]
# ## 6.3.1 Start the Contact Web Server
# To start the web service, open a JupyterLab terminal.  You can do this by first opening the JupyterLab Launcher (small '+' sign at the top of the file browser) and clicking the "Terminal" icon.  Next, enter the following in the terminal to start the app server:
#
# ```sh
# cd /dli/task/contact-app
# npm install
# npm run start
# ```

# %%
# Run this cell, then click the link to open a terminal
# Enter the commands provided above in the terminal window to start the web server
from IPython.display import HTML
HTML('<a href="", data-commandlinker-command="terminal:create-new">Open Terminal</a>')
# Out:
# <a href="", data-commandlinker-command="terminal:create-new">Open Terminal</a>

# %% [markdown]
# In the terminal window, you should see that the server has started running on port 8009:
#
# <img src="images/asr/webserver_running.png">
#
# After you have started the server, execute the following cell to create a link to open the app!

# %%
# %%js
# const href = window.location.hostname + '/app/';
# let a = document.createElement('a');
# let link = document.createTextNode('Open Riva Contact!');
# a.appendChild(link);
# a.href = "http://" + href;
# a.style.color = "navy"
# a.target = "_blank"
# element.append(a);

# %% [markdown]
# When you open the app, you may see a "Lost connection to server" alert.  Just click "Ok".  Other than that, your initial view should look like the following:
#
# <img src="images/asr/riva_contact_start.png">

# %% [markdown]
# <h3> ***WARNING Browser Restrictions WARNING***</h3>
#
# To use the web app, access to your microphone is required (camera is optional).<br>
# Several browsers restrict camera/microphone access to applications served from a secure origin (HTTPS or local IP).
# For your own development purposes, you can set up a self-signed certificate or proxy.
#
# Some browsers provide a way to treat specific URLs as secure:
# - Chrome browser: <br>
# Configure the "treat insecure origin as secure" flag by adding the application URL on the following page: <br>
#    ***chrome://flags/#unsafely-treat-insecure-origin-as-secure***<br>
# (Copy and paste this "chrome://" link to a tab on your browser to open the page) <br>
# You'll see the flag with a text window at the top of the page.  Add your own course URL to the box.  Here is an example (your URL is different).<br>
# More discussion can be found in [this blog](https://medium.com/@Carmichaelize/enabling-the-microphone-camera-in-chrome-for-local-unsecure-origins-9c90c3149339).
#
# <img src="images/asr/chrome_override_example.png">
#
# - Safari browser: <br>
# Enable in the menu: Develop > WebRTC > Allow Media Capture on Insecure Sites
#
# This will require you to restart the browser. No worries, nothing will be lost.
#
# Go to the Application URL. Once the page is loaded, you're welcome to start the Riva transcription.
# In the box titled "Riva transcription," hit the "Start" button, then start speaking. You'll see in-progress transcripts in the text field at the bottom. As those transcripts are finalized, they'll appear, with NER annotations, in the transcription box.

# %% [markdown]
# ## 6.3.2 Direct NER
#
# It is also possible to call the NER service directly without speaking. Type into the text field at the bottom and hit the "Submit" button. This will directly call the NER capability exposed by Riva with the submitted text (without calling the ASR service).

# %% [markdown]
# ## 6.3.3 Stop Riva Services

# %%
# Shut down Riva 
# !bash $RIVA_QS/riva_stop.sh
# Shut down web app
# !pkill -9 node

# %% [markdown]
# ---
# <h2 style="color:green;">Congratulations!</h2>
#
# In this notebook, you have:
# - Started ASR and NER default Riva services
# - Launched the Riva Contact app
# - Demonstrated live streaming ASR with NER for yourself!
#
# This concludes the ASR portion of the course.  Next, you'll start a deeper dive into NLP services, beginning with the [NER fine-tuning notebook](007_NLP_Finetune_NER.ipynb).

# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>
